# %% [markdown]
# # Droplet Generation Rate Analysis
# ## Video Processing by Python

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
! pip install --upgrad setuptools
! pip install opencv-python
# Out:
# Usage:
#   pip install [options] <requirement specifier> [package-index-options] ...
#   pip install [options] -r <requirements file> [package-index-options] ...
#   pip install [options] [-e] <vcs project url> ...
#   pip install [options] [-e] <local project path> ...
#   pip install [options] <archive url/path> ...
#
# ambiguous option: --upgrad (--upgrade, --upgrade-strategy?)
# ...
#     100% |████████████████████████████████| 41.2MB 18kB/s  eta 0:00:01 0% |▏                               | 215kB 6.7MB/s eta 0:00:07    13% |████▎                           | 5.5MB 8.6MB/s eta 0:00:05
# ...

# %%
import numpy as np
import cv2
import sys

# %%
#Image Processing Tool

img = cv2.imread('150-10.bmp')
show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(show_img)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#Video Processing Tool
# %pylab inline
from IPython.display import clear_output

mylist = []
i=0
#Read Video and Display
cap = cv2.VideoCapture('250,10-1.mp4')

if cap.isOpened()==False:
    print("Error Loading the file")
    
while(cap.isOpened()):

    ret, frame = cap.read()
    
    if not ret:
        cap.release()
        print("Released Video Resource")
        break
    
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    mylist.append(frame[500,1200])
    
    title("Input Stream")
    imshow(frame)
    show()
    clear_output(wait=True)
    
    i=i+1
    if i==40:
        break

x = np.arange(len(mylist))
plt.plot(x,mylist)
plt.show
    
cap.release()
cv2.destroyAllWindows()

# %%
sp = np.fft.fft(mylist)
freq = np.fft.fftfreq(x.shape[-1])
plt.plot(freq, sp.real)
